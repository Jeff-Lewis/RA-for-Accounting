# %%
# web scraper to get the data from mls.com
import requests
from bs4 import BeautifulSoup
import json

# URL of the page to scrape
url = 'https://mls.foreclosure.com/listing/search.html?ci=austin&st=tx'

# Send an HTTP GET request to the URL
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}
response = requests.get(url, headers=headers)

# Parse the HTML content of the page
soup = BeautifulSoup(response.text, 'html.parser')

# Look for script tags since the data is embedded in a script as JSON
scripts = soup.find_all('script', type='application/ld+json')

# This will store each property's details
properties = []

for script in scripts:
    # The JSON data is inside a <script> tag, extract and parse it
    try:
        data = json.loads(script.string)
        properties.append({
            'street_address': data.get('streetAddress'),
            'locality': data.get('addressLocality'),
            'region': data.get('addressRegion'),
            'postal_code': data.get('postalCode'),
            'latitude': data.get('geo', {}).get('latitude'),
            'longitude': data.get('geo', {}).get('longitude'),
            'details_url': data.get('url'),
            # If more details like bedrooms are consistently formatted, add them here
        })
    except json.JSONDecodeError:
        # If JSON decoding fails, skip to the next script tag
        continue

# # Now, `properties` list will contain all the property details that could be extracted
# for property in properties:
#     print(property)

print('Number of properties:', len(properties))
# Out:
# Number of properties: 25

# %%
from tomlkit import key


property = properties[0]
details_url = property['details_url']

response = requests.get(details_url, headers=headers)
# `print(response.text)` is displaying the raw HTML content of the response received after sending an
# HTTP GET request to the URL specified in the `details_url` variable. This can help you inspect the
# structure of the webpage and understand how the data is organized, which is useful for further
# parsing and extracting specific information from the webpage.
# print(response.text)
soup = BeautifulSoup(response.text, 'html.parser')
# Dictionary to hold the property information
property_info = {}

# Find all the 'li' elements with class 'lci'
info_items = soup.find_all('li', class_='lci')

for item in info_items:
    # The label is contained within a span with class 'attr-label'
    label_span = item.find('span', class_='attr-label')
    # The value is the text of a following 'a' tag, but it's behind a login
    value_a = item.find('a')
    
    # Extract the text from the span and 'a' tag
    label = label_span.get_text(strip=True) if label_span else None
    value = value_a.get_text(strip=True) if value_a else 'Details require login'

    # Add to the dictionary
    if label:
        property_info[label] = value

# print(f'{key}: {value}' for key, value in property_info.items())
print(property_info)
# Out:
# {'Day(s) On Site:': 'Join now for details', 'Trustee Name:': 'Join now for details', 'Trustee Address:': 'Join now for details', 'Trustee City:': 'Join now for details', 'Trustee State:': 'Join now for details', 'Trustee Zip:': 'Join now for details', 'Trustee Phone:': 'Join now for details', 'Court Name:': 'Join now for details', 'Court Address:': 'Join now for details', 'Attorney Law Firm:': 'Join now for details', 'Attorney Name:': 'Join now for details', 'Attorney Address:': 'Join now for details', 'Attorney City:': 'Join now for details', 'Attorney State:': 'Join now for details', 'Attorney Zip:': 'Join now for details', 'Case Number:': 'Join now for details', 'Filing Date:': 'Join now for details', 'Filing Type:': 'Join now for details', 'Debtor Name:': 'Join now for details', 'Record Type:': 'Join now for details', 'County Site:': 'Join now for details', 'County Appraiser Site:': 'Join now for details'}

# %%
# not working
image_urls = []

# Find all image tags and extract their 'src' attributes
for img_tag in soup.find_all('img'):
    img_url = img_tag.get('src')
    if img_url:  # Only add if the URL is not None
        image_urls.append(img_url)

# Now you have all image URLs in the image_urls list
for url in image_urls:
    print(url)
# Out:
# //dlvp94zy6vayf.cloudfront.net/static/css/cobrands/mls/mls_logo-78f50000b9bad0793cf75e320e633cb5.png
# //dlvp94zy6vayf.cloudfront.net/static/css/cobrands/fdc/img/big-fdc-logo-print-f8a6264f13df20b3ebda402031729639.png
# //dlvp94zy6vayf.cloudfront.net/static/css/img/FDC_logo_109x30-93d8fad80ef25c8ba28ca11651b9cba4.png

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time

# Set up the Selenium WebDriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')  # Run in headless mode, without a UI
options.add_argument('--disable-gpu')  # Disable GPU hardware acceleration
options.add_argument('--no-sandbox')  # Disable the sandbox for the Chrome driver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# Navigate to the page URL
driver.get(details_url)

# Wait for JavaScript to load
time.sleep(5)  # Adjust the sleep time as necessary

# Find the image tag with the class 'img-responsive'
img_tags = driver.find_elements(By.CLASS_NAME, 'img-responsive')

# List to store image source URLs
img_sources = []

# Get the 'src' attribute from each image tag
for img in img_tags:
    img_src = img.get_attribute('src')
    if img_src:  # Only add if the src is not None or empty
        img_sources.append(img_src)

# Print out the image source URLs
for src in img_sources:
    print(src)

# Quit the browser
driver.quit()
# Out:
# https://dlvp94zy6vayf.cloudfront.net/listingphoto/GJYFSQ3XPFGUK6SYHBPXSSLDGB4XA5DNGU2WC422NQZTSUDSIRVVIWRQOFMWESDVOJZGG===.jpg
# https://dlvp94zy6vayf.cloudfront.net/listingphoto/L5HFGZTMKRSS25SOKFNDOSTHNE3XMUDMJU2UOTJWLJLDC3CRONMFIWRQOFMWESDVOJZGG===.jpg
# https://dlvp94zy6vayf.cloudfront.net/listingphoto/KVYGSMDQGF2WUY2TKRJFAYLOINSVGTCVNBLXC4DKGZVDM33MNN3VIWRQOFMWESDVOJZGG===.jpg
# https://dlvp94zy6vayf.cloudfront.net/listingphoto/JRJG66SUMQ2WCS3FKV2TGWKLLBRHCLLMGYYGU327IRLUOV2MOJUFIWRQOFMWESDVOJZGG===.jpg
# https://dlvp94zy6vayf.cloudfront.net/listingphoto/JI3HMT2RGBIDGTSCOJVHKMDVKRCTOVDYJI3UUUJTNEWVOWTTNBGQ====.jpg
# https://dlvp94zy6vayf.cloudfront.net/listingphoto/KVJUQZTDPIYDK5DPPFHTOTSGGM2G65DQOZTFMV2GLF3VKMCTMZQVIWRQOFMWESDVOJZGG===.jpg
# https://dlvp94zy6vayf.cloudfront.net/listingphoto/KI2HSRSYGRHFKZKUGF2W4X3GKZBTARLCKBLXQMSONJTDI3TYFVUVIWRQOFMWESDVOJZGG===.jpg
# https://dlvp94zy6vayf.cloudfront.net/listingphoto/ORAWI3SXOE2DC6DDGZGC2QSONEZXG3RYKVRDSQLRJJDEUV2VJ5RFIWRQOFMWESDVOJZGG===.jpg
# https://dlvp94zy6vayf.cloudfront.net/listingphoto/MJWGY5CKHFKS2V3BJZGGEMC2IRTWY2JNGEYGU327IRLUOV2MOJUFIWRQOFMWESDVOJZGG===.jpg
# https://dlvp94zy6vayf.cloudfront.net/listingphoto/J55EQQKLNBEE6V3VIFBDC5LHG5XDK2BTJI2WC422NQZTSUDSIRVVIWRQOFMWESDVOJZGG===.jpg
# https://dlvp94zy6vayf.cloudfront.net/listingphoto/ONIDQ42KKVVFUOCIKFAUOUZZLBMVK33UKMYGU327IRLUOV2MOJUFIWRQOFMWESDVOJZGG===.jpg
# https://dlvp94zy6vayf.cloudfront.net/listingphoto/JRYWU23DOVVUOTSHIN2G2UDZGFJEES2WOVPVMV2GLF3VKMCTMZQVIWRQOFMWESDVOJZGG===.jpg
# https://dlvp94zy6vayf.cloudfront.net/listingphoto/KI3GG22SHFUG24CHMZYGE227HE4WY3TXJJZDSQLRJJDEUV2VJ5RFIWRQOFMWESDVOJZGG===.jpg
# https://dlvp94zy6vayf.cloudfront.net/listingphoto/OE2HE6SNMQ3GYNRVGJWUYVLIJBWVGMLVGFYEOTJWLJLDC3CRONMFIWRQOFMWESDVOJZGG===.jpg
# https://dlvp94zy6vayf.cloudfront.net/listingphoto/GYYUYRKPPFFGEYLHG5REIQLINUYW2U3EHFWXQMSONJTDI3TYFVUVIWRQOFMWESDVOJZGG===.jpg
# https://dlvp94zy6vayf.cloudfront.net/listingphoto/JBVU4NBXORKTE2SMNIWXMZSNNVMUIM22GZLHO6TUMIWTE4LNIVAVIWRQOFMWESDVOJZGG===.jpg
# https://dlvp94zy6vayf.cloudfront.net/listingphoto/NJAW4UDKJZGGYQSIOZPUS2STNJBGKT3NLJKWU327IRLUOV2MOJUFIWRQOFMWESDVOJZGG===.jpg
# https://dlvp94zy6vayf.cloudfront.net/listingphoto/MN5DS4KFNNZTSN2ZJNFDAVZSINVU2N3ENNDXQMSONJTDI3TYFVUVIWRQOFMWESDVOJZGG===.jpg

# %%
import requests
from bs4 import BeautifulSoup
import json

# Define the base URL for relative links
base_url = 'https://mls.foreclosure.com'

# URL of the page to scrape
search_url = 'https://mls.foreclosure.com/listing/search.html?ci=austin&st=tx'

# Send an HTTP GET request to the URL
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}
response = requests.get(search_url, headers=headers)

# Parse the HTML content of the page
soup = BeautifulSoup(response.text, 'html.parser')

# Look for script tags since the data is embedded in a script as JSON
scripts = soup.find_all('script', type='application/ld+json')

# This will store each property's basic details
properties = []

# Extract basic details from JSON data
for script in scripts:
    try:
        data = json.loads(script.string)
        properties.append({
            'street_address': data.get('streetAddress'),
            'locality': data.get('addressLocality'),
            'region': data.get('addressRegion'),
            'postal_code': data.get('postalCode'),
            'latitude': data.get('geo', {}).get('latitude'),
            'longitude': data.get('geo', {}).get('longitude'),
            'details_url': data.get('url'),
        })
    except json.JSONDecodeError:
        continue

# Iterate over each property to get detailed information
for property in properties:
    details_url = property['details_url']
    if not details_url.startswith('http'):
        details_url = base_url + details_url  # Make sure the URL is complete
    
    response = requests.get(details_url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Dictionary to hold the property information
    property_info = {}
    
    # Find all the 'li' elements with class 'lci' for detailed info
    info_items = soup.find_all('li', class_='lci')
    for item in info_items:
        label_span = item.find('span', class_='attr-label')
        value_a = item.find('a')
        label = label_span.get_text(strip=True) if label_span else None
        value = value_a.get_text(strip=True) if value_a else 'Details require login'
        if label:
            property_info[label] = value

    # Add the detailed info to the property's data
    property.update(property_info)

# Now, `properties` list will contain all the property details
for property in properties:
    print(property)
# Out:
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.209', 'longitude': '-97.793', 'details_url': 'https://mls.foreclosure.com/address/Homespun-Rd-Austin-TX-78745/61749800_lid', 'Day(s) On Site:': 'Join now for details', 'Trustee Name:': 'Join now for details', 'Trustee Address:': 'Join now for details', 'Trustee City:': 'Join now for details', 'Trustee State:': 'Join now for details', 'Trustee Zip:': 'Join now for details', 'Trustee Phone:': 'Join now for details', 'Court Name:': 'Join now for details', 'Court Address:': 'Join now for details', 'Attorney Law Firm:': 'Join now for details', 'Attorney Name:': 'Join now for details', 'Attorney Address:': 'Join now for details', 'Attorney City:': 'Join now for details', 'Attorney State:': 'Join now for details', 'Attorney Zip:': 'Join now for details', 'Case Number:': 'Join now for details', 'Filing Date:': 'Join now for details', 'Filing Type:': 'Join now for details', 'Debtor Name:': 'Join now for details', 'Record Type:': 'Join now for details', 'County Site:': 'Join now for details', 'County Appraiser Site:': 'Join now for details'}
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.302', 'longitude': '-97.932', 'details_url': 'https://mls.foreclosure.com/address/W-Highway-71-Bee-Cave-TX-78738/61750938_lid', 'Day(s) On Site:': 'Join now for details', 'Court Name:': 'Join now for details', 'Court Address:': 'Join now for details', 'Attorney Law Firm:': 'Join now for details', 'Attorney Name:': 'Join now for details', 'Attorney Address:': 'Join now for details', 'Attorney City:': 'Join now for details', 'Attorney State:': 'Join now for details', 'Attorney Zip:': 'Join now for details', 'Case Number:': 'Join now for details', 'Filing Date:': 'Join now for details', 'Filing Type:': 'Join now for details', 'Debtor Name:': 'Join now for details', 'Record Type:': 'Join now for details', 'County Site:': 'Join now for details', 'County Appraiser Site:': 'Join now for details'}
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.273', 'longitude': '-97.663', 'details_url': 'https://mls.foreclosure.com/address/Ed-Bluestein-Blvd-Austin-TX-78721/61742859_lid'}
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.357', 'longitude': '-97.701', 'details_url': 'https://mls.foreclosure.com/address/N-Lamar-Blvd-Austin-TX-78753/61742867_lid'}
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.315', 'longitude': '-97.694', 'details_url': 'https://mls.foreclosure.com/address/Dunbury-Dr-Austin-TX-78723/61742873_lid'}
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.269', 'longitude': '-97.789', 'details_url': 'https://mls.foreclosure.com/address/Liberty-Park-401-Austin-TX-78746/61742954_lid'}
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.306', 'longitude': '-97.713', 'details_url': 'https://mls.foreclosure.com/address/N-Interstate-35-Austin-TX-78751/61743085_lid'}
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.332', 'longitude': '-97.647', 'details_url': 'https://mls.foreclosure.com/address/Wellesley-Dr-Austin-TX-78754/61736823_lid'}
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.340', 'longitude': '-97.917', 'details_url': 'https://mls.foreclosure.com/address/Santaluz-Path-Austin-TX-78732/61736843_lid'}
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.267', 'longitude': '-97.724', 'details_url': 'https://mls.foreclosure.com/address/E-11th-St-Austin-TX-78702/61736891_lid'}
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.132', 'longitude': '-97.773', 'details_url': 'https://mls.foreclosure.com/address/Lehman-Way-Austin-TX-78747/61737022_lid'}
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.292', 'longitude': '-97.671', 'details_url': 'https://mls.foreclosure.com/address/Sigman-Ln-Austin-TX-78723/61737152_lid'}
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.343', 'longitude': '-97.711', 'details_url': 'https://mls.foreclosure.com/address/Guadalupe-St-Apt-103-Austin-TX-78752/61737166_lid'}
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.327', 'longitude': '-97.753', 'details_url': 'https://mls.foreclosure.com/address/W-Park-Dr-Austin-TX-78731/61737628_lid'}
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.336', 'longitude': '-97.651', 'details_url': 'https://mls.foreclosure.com/address/Ferguson-Ln-Austin-TX-78754/61737827_lid'}
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.390', 'longitude': '-97.656', 'details_url': 'https://mls.foreclosure.com/address/Shropshire-Blvd-Austin-TX-78753/61737847_lid'}
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.265', 'longitude': '-97.811', 'details_url': 'https://mls.foreclosure.com/address/Stoneridge-Rd--1-Austin-TX-78746/61740188_lid'}
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.351', 'longitude': '-97.701', 'details_url': 'https://mls.foreclosure.com/address/E-Walnut-Dr-Austin-TX-78753/61740946_lid', 'Day(s) On Site:': 'Join now for details', 'Trustee Name:': 'Join now for details', 'Trustee Address:': 'Join now for details', 'Trustee City:': 'Join now for details', 'Trustee State:': 'Join now for details', 'Trustee Zip:': 'Join now for details', 'Trustee Phone:': 'Join now for details', 'Court Name:': 'Join now for details', 'Court Address:': 'Join now for details', 'Attorney Law Firm:': 'Join now for details', 'Attorney Name:': 'Join now for details', 'Attorney Address:': 'Join now for details', 'Attorney City:': 'Join now for details', 'Attorney State:': 'Join now for details', 'Attorney Zip:': 'Join now for details', 'Case Number:': 'Join now for details', 'Filing Date:': 'Join now for details', 'Filing Type:': 'Join now for details', 'Debtor Name:': 'Join now for details', 'Record Type:': 'Join now for details', 'County Site:': 'Join now for details', 'County Appraiser Site:': 'Join now for details'}
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.241', 'longitude': '-97.939', 'details_url': 'https://mls.foreclosure.com/address/Circle-Dr-Austin-TX-78736/61737346_lid'}
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.436', 'longitude': '-97.778', 'details_url': 'https://mls.foreclosure.com/address/Fathom-Cir-Apt-403-Austin-TX-78750/61735378_lid', 'Day(s) On Site:': 'Join now for details', 'Trustee Name:': 'Join now for details', 'Trustee Address:': 'Join now for details', 'Trustee City:': 'Join now for details', 'Trustee State:': 'Join now for details', 'Trustee Zip:': 'Join now for details', 'Trustee Phone:': 'Join now for details', 'Court Name:': 'Join now for details', 'Court Address:': 'Join now for details', 'Attorney Law Firm:': 'Join now for details', 'Attorney Name:': 'Join now for details', 'Attorney Address:': 'Join now for details', 'Attorney City:': 'Join now for details', 'Attorney State:': 'Join now for details', 'Attorney Zip:': 'Join now for details', 'Case Number:': 'Join now for details', 'Filing Date:': 'Join now for details', 'Filing Type:': 'Join now for details', 'Debtor Name:': 'Join now for details', 'Record Type:': 'Join now for details', 'County Site:': 'Join now for details', 'County Appraiser Site:': 'Join now for details'}
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.332', 'longitude': '-97.650', 'details_url': 'https://mls.foreclosure.com/address/Wightman-Dr-Austin-TX-78754/61734640_lid', 'Bathrooms:': 'Join now for details', 'Living Area Size:': 'Join now for details', 'Year Built:': 'Join now for details', 'Day(s) On Site:': 'Join now for details', 'Subdivision:': 'Join now for details', 'Property Type:': 'Join now for details', 'Trustee Name:': 'Join now for details', 'Trustee Address:': 'Join now for details', 'Trustee City:': 'Join now for details', 'Trustee State:': 'Join now for details', 'Trustee Zip:': 'Join now for details', 'Trustee Phone:': 'Join now for details', 'Court Name:': 'Join now for details', 'Court Address:': 'Join now for details', 'Baths:': 'Join now for details', 'Full Baths:': 'Join now for details', 'No. of Stories:': 'Join now for details', 'Parking:': 'Join now for details', 'Parking Sqft:': 'Join now for details', 'Air Conditioning:': 'Join now for details', 'Fireplaces:': 'Join now for details', 'Construction Type:': 'Join now for details', 'Foundation Type:': 'Join now for details', 'Heating Type:': 'Join now for details', 'Roof Material:': 'Join now for details', 'Roof Type:': 'Join now for details', 'Land Area Sqft:': 'Join now for details', 'APN:': 'Join now for details', 'Front Footage:': 'Join now for details', 'Depth Footage:': 'Join now for details', 'Living Sqft:': 'Join now for details', 'Garage:': 'Join now for details', 'Attorney Name:': 'Join now for details', 'Attorney Address:': 'Join now for details', 'Attorney City:': 'Join now for details', 'Attorney State:': 'Join now for details', 'Attorney Zip:': 'Join now for details', 'Case Number:': 'Join now for details', 'Filing Date:': 'Join now for details', 'Filing Type:': 'Join now for details', 'Debtor Name:': 'Join now for details', 'Record Type:': 'Join now for details', 'County Site:': 'Join now for details', 'County Appraiser Site:': 'Join now for details'}
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.264', 'longitude': '-97.745', 'details_url': 'https://mls.foreclosure.com/address/Colorado-St--13-Austin-TX-78701/61734642_lid', 'Day(s) On Site:': 'Join now for details', 'Trustee Name:': 'Join now for details', 'Trustee Address:': 'Join now for details', 'Trustee City:': 'Join now for details', 'Trustee State:': 'Join now for details', 'Trustee Zip:': 'Join now for details', 'Trustee Phone:': 'Join now for details', 'Court Name:': 'Join now for details', 'Court Address:': 'Join now for details', 'Attorney Law Firm:': 'Join now for details', 'Attorney Name:': 'Join now for details', 'Attorney Address:': 'Join now for details', 'Attorney City:': 'Join now for details', 'Attorney State:': 'Join now for details', 'Attorney Zip:': 'Join now for details', 'Case Number:': 'Join now for details', 'Filing Date:': 'Join now for details', 'Filing Type:': 'Join now for details', 'Debtor Name:': 'Join now for details', 'Record Type:': 'Join now for details', 'County Site:': 'Join now for details', 'County Appraiser Site:': 'Join now for details'}
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.309', 'longitude': '-97.928', 'details_url': 'https://mls.foreclosure.com/address/Reims-Ct-Austin-TX-78738/61731697_lid'}
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.414', 'longitude': '-97.845', 'details_url': 'https://mls.foreclosure.com/address/N-Fm-620-Apt-620-Austin-TX-78726/61727701_lid', 'Day(s) On Site:': 'Join now for details', 'Trustee Name:': 'Join now for details', 'Trustee Address:': 'Join now for details', 'Trustee City:': 'Join now for details', 'Trustee State:': 'Join now for details', 'Trustee Zip:': 'Join now for details', 'Trustee Phone:': 'Join now for details', 'Court Name:': 'Join now for details', 'Court Address:': 'Join now for details', 'Case Number:': 'Join now for details', 'Filing Date:': 'Join now for details', 'Filing Type:': 'Join now for details', 'Debtor Name:': 'Join now for details', 'Record Type:': 'Join now for details', 'County Site:': 'Join now for details', 'County Appraiser Site:': 'Join now for details'}
# {'street_address': None, 'locality': None, 'region': None, 'postal_code': None, 'latitude': '30.448', 'longitude': '-97.813', 'details_url': 'https://mls.foreclosure.com/address/Sandy-Loam-Trl-Austin-TX-78750/61723694_lid'}

# %%
for property in properties:
    for key, value in property.items():
        if value == None:
            continue
        print(f'{key}: {value}')
# Out:
# latitude: 30.209
# longitude: -97.793
# details_url: https://mls.foreclosure.com/address/Homespun-Rd-Austin-TX-78745/61749800_lid
# Day(s) On Site:: Join now for details
# Trustee Name:: Join now for details
# Trustee Address:: Join now for details
# Trustee City:: Join now for details
# Trustee State:: Join now for details
# Trustee Zip:: Join now for details
# Trustee Phone:: Join now for details
# Court Name:: Join now for details
# Court Address:: Join now for details
# Attorney Law Firm:: Join now for details
# Attorney Name:: Join now for details
# Attorney Address:: Join now for details
# Attorney City:: Join now for details
# Attorney State:: Join now for details
# Attorney Zip:: Join now for details
# Case Number:: Join now for details
# Filing Date:: Join now for details
# Filing Type:: Join now for details
# Debtor Name:: Join now for details
# Record Type:: Join now for details
# County Site:: Join now for details
# County Appraiser Site:: Join now for details
# latitude: 30.302
# longitude: -97.932
# details_url: https://mls.foreclosure.com/address/W-Highway-71-Bee-Cave-TX-78738/61750938_lid
# Day(s) On Site:: Join now for details
# Court Name:: Join now for details
# Court Address:: Join now for details
# Attorney Law Firm:: Join now for details
# Attorney Name:: Join now for details
# Attorney Address:: Join now for details
# Attorney City:: Join now for details
# Attorney State:: Join now for details
# Attorney Zip:: Join now for details
# Case Number:: Join now for details
# Filing Date:: Join now for details
# Filing Type:: Join now for details
# Debtor Name:: Join now for details
# Record Type:: Join now for details
# County Site:: Join now for details
# County Appraiser Site:: Join now for details
# latitude: 30.273
# longitude: -97.663
# details_url: https://mls.foreclosure.com/address/Ed-Bluestein-Blvd-Austin-TX-78721/61742859_lid
# latitude: 30.357
# longitude: -97.701
# details_url: https://mls.foreclosure.com/address/N-Lamar-Blvd-Austin-TX-78753/61742867_lid
# latitude: 30.315
# longitude: -97.694
# details_url: https://mls.foreclosure.com/address/Dunbury-Dr-Austin-TX-78723/61742873_lid
# latitude: 30.269
# longitude: -97.789
# details_url: https://mls.foreclosure.com/address/Liberty-Park-401-Austin-TX-78746/61742954_lid
# latitude: 30.306
# longitude: -97.713
# details_url: https://mls.foreclosure.com/address/N-Interstate-35-Austin-TX-78751/61743085_lid
# latitude: 30.332
# longitude: -97.647
# details_url: https://mls.foreclosure.com/address/Wellesley-Dr-Austin-TX-78754/61736823_lid
# latitude: 30.340
# longitude: -97.917
# details_url: https://mls.foreclosure.com/address/Santaluz-Path-Austin-TX-78732/61736843_lid
# latitude: 30.267
# longitude: -97.724
# details_url: https://mls.foreclosure.com/address/E-11th-St-Austin-TX-78702/61736891_lid
# latitude: 30.132
# longitude: -97.773
# details_url: https://mls.foreclosure.com/address/Lehman-Way-Austin-TX-78747/61737022_lid
# latitude: 30.292
# longitude: -97.671
# details_url: https://mls.foreclosure.com/address/Sigman-Ln-Austin-TX-78723/61737152_lid
# latitude: 30.343
# longitude: -97.711
# details_url: https://mls.foreclosure.com/address/Guadalupe-St-Apt-103-Austin-TX-78752/61737166_lid
# latitude: 30.327
# longitude: -97.753
# details_url: https://mls.foreclosure.com/address/W-Park-Dr-Austin-TX-78731/61737628_lid
# latitude: 30.336
# longitude: -97.651
# details_url: https://mls.foreclosure.com/address/Ferguson-Ln-Austin-TX-78754/61737827_lid
# latitude: 30.390
# longitude: -97.656
# details_url: https://mls.foreclosure.com/address/Shropshire-Blvd-Austin-TX-78753/61737847_lid
# latitude: 30.265
# longitude: -97.811
# details_url: https://mls.foreclosure.com/address/Stoneridge-Rd--1-Austin-TX-78746/61740188_lid
# latitude: 30.351
# longitude: -97.701
# details_url: https://mls.foreclosure.com/address/E-Walnut-Dr-Austin-TX-78753/61740946_lid
# Day(s) On Site:: Join now for details
# Trustee Name:: Join now for details
# Trustee Address:: Join now for details
# Trustee City:: Join now for details
# Trustee State:: Join now for details
# Trustee Zip:: Join now for details
# Trustee Phone:: Join now for details
# Court Name:: Join now for details
# Court Address:: Join now for details
# Attorney Law Firm:: Join now for details
# Attorney Name:: Join now for details
# Attorney Address:: Join now for details
# Attorney City:: Join now for details
# Attorney State:: Join now for details
# Attorney Zip:: Join now for details
# Case Number:: Join now for details
# Filing Date:: Join now for details
# Filing Type:: Join now for details
# Debtor Name:: Join now for details
# Record Type:: Join now for details
# County Site:: Join now for details
# County Appraiser Site:: Join now for details
# latitude: 30.241
# longitude: -97.939
# details_url: https://mls.foreclosure.com/address/Circle-Dr-Austin-TX-78736/61737346_lid
# latitude: 30.436
# longitude: -97.778
# details_url: https://mls.foreclosure.com/address/Fathom-Cir-Apt-403-Austin-TX-78750/61735378_lid
# Day(s) On Site:: Join now for details
# Trustee Name:: Join now for details
# Trustee Address:: Join now for details
# Trustee City:: Join now for details
# Trustee State:: Join now for details
# Trustee Zip:: Join now for details
# Trustee Phone:: Join now for details
# Court Name:: Join now for details
# Court Address:: Join now for details
# Attorney Law Firm:: Join now for details
# Attorney Name:: Join now for details
# Attorney Address:: Join now for details
# Attorney City:: Join now for details
# Attorney State:: Join now for details
# Attorney Zip:: Join now for details
# Case Number:: Join now for details
# Filing Date:: Join now for details
# Filing Type:: Join now for details
# Debtor Name:: Join now for details
# Record Type:: Join now for details
# County Site:: Join now for details
# County Appraiser Site:: Join now for details
# latitude: 30.332
# longitude: -97.650
# details_url: https://mls.foreclosure.com/address/Wightman-Dr-Austin-TX-78754/61734640_lid
# Bathrooms:: Join now for details
# Living Area Size:: Join now for details
# Year Built:: Join now for details
# Day(s) On Site:: Join now for details
# Subdivision:: Join now for details
# Property Type:: Join now for details
# Trustee Name:: Join now for details
# Trustee Address:: Join now for details
# Trustee City:: Join now for details
# Trustee State:: Join now for details
# Trustee Zip:: Join now for details
# Trustee Phone:: Join now for details
# Court Name:: Join now for details
# Court Address:: Join now for details
# Baths:: Join now for details
# Full Baths:: Join now for details
# No. of Stories:: Join now for details
# Parking:: Join now for details
# Parking Sqft:: Join now for details
# Air Conditioning:: Join now for details
# Fireplaces:: Join now for details
# Construction Type:: Join now for details
# Foundation Type:: Join now for details
# Heating Type:: Join now for details
# Roof Material:: Join now for details
# Roof Type:: Join now for details
# Land Area Sqft:: Join now for details
# APN:: Join now for details
# Front Footage:: Join now for details
# Depth Footage:: Join now for details
# Living Sqft:: Join now for details
# Garage:: Join now for details
# Attorney Name:: Join now for details
# Attorney Address:: Join now for details
# Attorney City:: Join now for details
# Attorney State:: Join now for details
# Attorney Zip:: Join now for details
# Case Number:: Join now for details
# Filing Date:: Join now for details
# Filing Type:: Join now for details
# Debtor Name:: Join now for details
# Record Type:: Join now for details
# County Site:: Join now for details
# County Appraiser Site:: Join now for details
# latitude: 30.264
# longitude: -97.745
# details_url: https://mls.foreclosure.com/address/Colorado-St--13-Austin-TX-78701/61734642_lid
# Day(s) On Site:: Join now for details
# Trustee Name:: Join now for details
# Trustee Address:: Join now for details
# Trustee City:: Join now for details
# Trustee State:: Join now for details
# Trustee Zip:: Join now for details
# Trustee Phone:: Join now for details
# Court Name:: Join now for details
# Court Address:: Join now for details
# Attorney Law Firm:: Join now for details
# Attorney Name:: Join now for details
# Attorney Address:: Join now for details
# Attorney City:: Join now for details
# Attorney State:: Join now for details
# Attorney Zip:: Join now for details
# Case Number:: Join now for details
# Filing Date:: Join now for details
# Filing Type:: Join now for details
# Debtor Name:: Join now for details
# Record Type:: Join now for details
# County Site:: Join now for details
# County Appraiser Site:: Join now for details
# latitude: 30.309
# longitude: -97.928
# details_url: https://mls.foreclosure.com/address/Reims-Ct-Austin-TX-78738/61731697_lid
# latitude: 30.414
# longitude: -97.845
# details_url: https://mls.foreclosure.com/address/N-Fm-620-Apt-620-Austin-TX-78726/61727701_lid
# Day(s) On Site:: Join now for details
# Trustee Name:: Join now for details
# Trustee Address:: Join now for details
# Trustee City:: Join now for details
# Trustee State:: Join now for details
# Trustee Zip:: Join now for details
# Trustee Phone:: Join now for details
# Court Name:: Join now for details
# Court Address:: Join now for details
# Case Number:: Join now for details
# Filing Date:: Join now for details
# Filing Type:: Join now for details
# Debtor Name:: Join now for details
# Record Type:: Join now for details
# County Site:: Join now for details
# County Appraiser Site:: Join now for details
# latitude: 30.448
# longitude: -97.813
# details_url: https://mls.foreclosure.com/address/Sandy-Loam-Trl-Austin-TX-78750/61723694_lid

# %%
# test

details_url = 'https://mls.foreclosure.com/address/Ed-Bluestein-Blvd-Austin-TX-78721/61742859_lid'

response = requests.get(details_url, headers=headers)
# `print(response.text)` is displaying the raw HTML content of the response received after sending an
# HTTP GET request to the URL specified in the `details_url` variable. This can help you inspect the
# structure of the webpage and understand how the data is organized, which is useful for further
# parsing and extracting specific information from the webpage.
# print(response.text)
soup = BeautifulSoup(response.text, 'html.parser')
# Dictionary to hold the property information
property_info = {}

# Find all the 'li' elements with class 'lci'
info_items = soup.find_all('li', class_='lci')

for item in info_items:
    # The label is contained within a span with class 'attr-label'
    label_span = item.find('span', class_='attr-label')
    # The value is the text of a following 'a' tag, but it's behind a login
    value_a = item.find('a')
    
    # Extract the text from the span and 'a' tag
    label = label_span.get_text(strip=True) if label_span else None
    value = value_a.get_text(strip=True) if value_a else 'Details require login'

    # Add to the dictionary
    if label:
        property_info[label] = value

# print(f'{key}: {value}' for key, value in property_info.items())
print(property_info)
print(response.text)
# Out:
# {}
# <!doctype html>
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>
# <title>
# Ed Bluestein Blvd Austin Texas 78721 | mls.foreclosure.com </title>
# <style><!--
# //-->
# </style>
# <!--<link rel="stylesheet" type="text/css" href="//dlvp94zy6vayf.cloudfront.net/static/css/printstyle-612c7575c94c32eb6e97a2da48e8ca8e.css" media="print" />-->
# <meta name="description" content="This is a preforeclosure property located at in Austin, . View all the latest property details for homes in Austin, to get a feel for real estate in the neighborhood and/or surrounding area(s).">
# <meta name="keywords" content="Austin preforeclosure, Travis preforeclosure home, Travis County TX preforeclosure, preforeclosure property, Austin new preforeclosure">
# <meta property="og:type" content="foreclosure:home"/>
# <meta property="og:latitude" content="30.273388"/>
# <meta property="og:longitude" content="-97.662539"/>
# <meta property="og:street-address" content="Ed Bluestein Blvd"/>
# <meta property="og:locality" content="Austin"/>
# <meta property="og:region" content="Texas"/>
# <meta property="og:postal-code" content="78721"/>
# <meta property="og:country-name" content="United States"/>
# <meta property="og:url" content="https://mls.foreclosure.com/address/Ed-Bluestein-Blvd-Austin-TX-78721/61742859_lid"/>
# <meta property="og:title" content="Ed Bluestein Blvd Austin Texas 78721 | mls.foreclosure.com"/>
# <meta property="og:image" content=""/>
# <meta property="og:description" content="This is a property located at Ed Bluestein Blvd in Austin, Texas. View all the latest property details for homes in Austin, Texas to get a feel for real estate in the neighborhood and/or surrounding area(s)."/>
# <link rel="stylesheet" type="text/css" href="//dlvp94zy6vayf.cloudfront.net/static/css/cobrands/bootstrap_cobrand/infobox-e65144fda650369a908c04ad97258371.css" media="all" />
# <link rel="stylesheet" type="text/css" media="screen" href="//dlvp94zy6vayf.cloudfront.net/static/lib/thickbox-3_1/thickbox-62b5b7ceb0989e347ff85356cb6c7778.css" />
# <link rel="stylesheet" href="//dlvp94zy6vayf.cloudfront.net/static/lib/Gallery-2_15_2/css/blueimp-gallery.min-84ff75b7cb674e7476ec2e594e81e9a6.css"/>
# <link rel="stylesheet" type="text/css" href="//dlvp94zy6vayf.cloudfront.net/static/css/cobrands/bootstrap_cobrand/details-dcb11212dfba917cdeee1b3f8ce000a7.css" media="all" />
# <link rel="stylesheet" href="//dlvp94zy6vayf.cloudfront.net/static/css/cobrands/bootstrap_cobrand/agent-search-1af2fc2fdf38b036d7fb5afb98013c58.css"/>
# <script type="text/javascript" src="//dlvp94zy6vayf.cloudfront.net/static/lib/jquery/3.5.1/jquery.min-12b69d0ae6c6f0c42942ae6da2896e84.js"></script>
# <script type="text/javascript">$j = jQuery.noConflict();</script>
# <script src="//dlvp94zy6vayf.cloudfront.net/static/lib/jquery-maskedinput-1_4_0/jquery.maskedinput.min-7ca9553c56805a72add283b3d73c19ae.js" type="text/javascript"></script>
# <script>
# jQuery(function($){
# $("#phoneLetter").mask("(999) 999-9999");
# });
# </script>
# <script type="text/javascript">
# var ftlVars = {};
# ftlVars.hasAlbums = false;
# ftlVars.playLinkText = 'Play';
# ftlVars.pauseLinkText = 'Pause';
# ftlVars.prevLinkText = '&lsaquo; Previous';
# ftlVars.nextLinkText = 'Next &rsaquo;';
# ftlVars.nextPageLinkText = 'Next &rsaquo;';
# ftlVars.prevPageLinkText = '&lsaquo; Prev';
# ftlVars.numPhotosText = "'Number of photos: '+ (nextIndex+1) +' of '+ this.data.length";
# ftlVars.bingMapsKey = '';
# ftlVars.listingLatitude = '30.273';
# ftlVars.listingLongitude = '-97.663';
# ftlVars.previousSearch = '';
# ftlVars.currentListingId = 61742859;
# ftlVars.currentPage = 1;
# ftlVars.pageSize = 25;
# ftlVars.listingSearchIndex = 0;
# ftlVars.loggedOn = false;
# ftlVars.listingPrice = "";
# ftlVars.county ='';
# ftlVars.mobile = false;
# ftlVars.numberListingsSearch = 0;
# ftlVars.sendLetterToHomeowner = false;
# ftlVars.searchResultsWidget = false;
# ftlVars.detailsPageLinkName = 'listing';
# ftlVars.encryptedAccountId = '';
# ftlVars.isListHubListing = false;
# ftlVars.listingTypeName = 'preforeclosure';
# ftlVars.enableBuyingProcess = false;
# </script>
# <script src='//dlvp94zy6vayf.cloudfront.net/static/lib/boxover-2_1/boxover.js?v=2' type='text/javascript'></script>
# <script type="text/javascript" src="//dlvp94zy6vayf.cloudfront.net/static/lib/spinners-2/spin.min-40b401681f2576e98d98a88e8d27c983.js"></script>
# <script type="text/javascript" src="//dlvp94zy6vayf.cloudfront.net/static/lib/thickbox-3_1/thickbox-compressed-noConflict.js"></script>
# <link rel="stylesheet" href="//dlvp94zy6vayf.cloudfront.net/static/lib/thickbox-3_1/thickbox.css" type="text/css" media="screen" />
# <script type="text/javascript" src="//dlvp94zy6vayf.cloudfront.net/static/lib/bower_components/fancybox/source/jquery.fancybox.pack.js?v=2.1.5"></script>
# <link rel="stylesheet" type="text/css" href="//dlvp94zy6vayf.cloudfront.net/static/lib/bower_components/fancybox/source/jquery.fancybox.css?v=2.1.5" media="screen" />
# <script type="text/javascript" src="//dlvp94zy6vayf.cloudfront.net/static/css/cobrands/bootstrap_cobrand/js/details-3119b569d39596cdfa7f905a90f4d506.js"></script>
# <script>
# var AVM_BOX_WIDTH = 260;
# var AVM_BOX_HEIGHT = 150;
# var AVM_BOX_HOVER_WIDTH = 150;
# var AVM_BOX_HOVER_HEIGHT = 40;
# var bootstrap = window.bootstrap || {};
# bootstrap.appPath = '';
# bootstrap.digitalMaps = false;
# bootstrap.digitalMapsKey = "";
# bootstrap.loggedOn = false;
# bootstrap.listingAddressToken = "ed_bluestein_blvd-austin-tx";
# </script>
# <style>
# .nearbyProperties {
# background: none repeat scroll 0 0 #000000;
# border-radius: 5px;
# cursor: pointer !important;
# }
# #fixed-details h1.region {
# font-size: 18px;
# }
# #ashiInspectorContainer { border: 1px solid #ccc; margin: 20px 0; }
# #ashiInspectorContainer .inspector-header{ padding: 10px;}
# #ashiInspectorContainer .inspector-header h2 { margin: 0px; font-size: 22px; }
# #ashiInspectorContainer .inspector{ margin: 5px; padding: 5px; }
# #ashiInspectorContainer .inspector .title { font-weight:bold; }
# #ashiInspectorContainer .inspector a{ color: #555; text-decoration:none; }
# #ashiInspectorContainer .inspector-list .inspector:nth-child(odd){ background-color: #eeeeee; }
# #ashiInspectorContainer .homeInspectorTitle{margin: 0px; font-size: 22px;font-weight: 500;}
# .detailsAdvertiseLink a{text-decoration:none;color:#555;font-size: 12px;margin-right: 3px;}
# </style>
# <meta charset="utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=edge" />
# <meta name="viewport" content="width=device-width, initial-scale=1" />
# <meta name="apple-mobile-web-app-capable" content="yes" />
# <meta name="apple-mobile-web-app-status-bar-style" content="black" />
# <meta name="mobile-web-app-capable" content="yes" />
# <script type='text/javascript'>
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# (function() {
# var gads = document.createElement('script');
# gads.async = true;
# gads.type = 'text/javascript';
# var useSSL = 'https:' == document.location.protocol;
# gads.src = (useSSL ? 'https:' : 'http:') +
# '//www.googletagservices.com/tag/js/gpt.js';
# var node = document.getElementsByTagName('script')[0];
# node.parentNode.insertBefore(gads, node);
# })();
# </script>
# <!-- Google tag (gtag.js) -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-HGJ16XKTGQ"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'G-HGJ16XKTGQ');
# </script>
# <!-- Bootstrap Core CSS -->
# <link href="//dlvp94zy6vayf.cloudfront.net/static/lib/bootstrap-3_3_1/css/bootstrap.min-3ab3438f85ad9f9e27e1af1facf0a9c4.css" rel="stylesheet" media="screen,print">
# <link rel="stylesheet" href="//dlvp94zy6vayf.cloudfront.net/static/lib/fontAwesome-3.2.1/css/font-awesome.min-4bd5140a31e85c494a074c3bd2eb9de1.css" media="screen">
# <!-- Custom CSS -->
# <link href="//dlvp94zy6vayf.cloudfront.net/static/css/cobrands/mls/v2/css/custom-f61f42844fbd2de0c8203c5669f0f15b.css" rel="stylesheet">
# <link href="//dlvp94zy6vayf.cloudfront.net/static/css/cobrands/mls/bootstrap-2dabe83cf4f54f0da8f2f0bd2286d546.css" rel="stylesheet">
# <link href="//dlvp94zy6vayf.cloudfront.net/static/css/cobrands/mls/superfish-1968b4b0acf541c293accd63ffca969d.css" rel="stylesheet">
# <link href="//dlvp94zy6vayf.cloudfront.net/static/css/cobrands/mls/main-597f547fe9ff28328d99596b975ec9a1.css" rel="stylesheet">
# <!-- Custom Fonts -->
# <link href="https://fonts.googleapis.com/css?family=Lato:300,400,700,300italic,400italic,700italic" rel="stylesheet" type="text/css">
# <script type="text/javascript" src="//dlvp94zy6vayf.cloudfront.net/static/lib/jquery-migrate/3.2.0/jquery-migrate.min-dca9a74aeb0052e044db2f928db920d0.js"></script>
# <link rel="stylesheet" href="//dlvp94zy6vayf.cloudfront.net/static/lib/jqueryui/1.12.1/themes/smoothness/jquery-ui.min-3c2a865c832a1322285c55c6ed99abb2.css"><script src="//dlvp94zy6vayf.cloudfront.net/static/lib/jqueryui/1.12.1/jquery-ui.min-0a497d4661df7b82feee14332ce0bdaf.js"></script>
# <link rel="stylesheet" href="//dlvp94zy6vayf.cloudfront.net/static/css/cobrands/bootstrap_cobrand/main-ea59f64ac16324a521645164b5fa4193.css" type="text/css"/>
# <link rel="apple-touch-icon" sizes="180x180" href="//dlvp94zy6vayf.cloudfront.net/static/css/cobrands/mls/v2/img/apple-touch-icon-d3011d9ce4aaf355c84ec4dcf507e05b.png">
# <link rel="icon" type="image/png" href="//dlvp94zy6vayf.cloudfront.net/static/css/cobrands/mls/v2/img/favicon-32x32-2ce892c75f7ba5909c450259bdc6f0f2.png" sizes="32x32">
# <link rel="icon" type="image/png" href="//dlvp94zy6vayf.cloudfront.net/static/css/cobrands/mls/v2/img/favicon-16x16-17ac73db1983c32a07394b0c1b7ff02b.png" sizes="16x16">
# <link rel="manifest" href="//dlvp94zy6vayf.cloudfront.net/static/css/cobrands/mls/v2/img/manifest-dc79e7bcc596f6b955e83a7017341740.json">
# <link rel="mask-icon" href="//dlvp94zy6vayf.cloudfront.net/static/css/cobrands/mls/v2/img/safari-pinned-tab-a4161c7d05721e3bfeab3105142c2ec3.svg" color="#5bbad5">
# <meta name="theme-color" content="#ffffff"/>
# <!--[if lt IE 9]>
# <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>
# <script src="https://oss.maxcdn.com/libs/respond.js/1.4.2/respond.min.js"></script>
# <![endif]-->
# <script src="//dlvp94zy6vayf.cloudfront.net/static/lib/bootstrap-3_3_1/js/bootstrap.min-2616d3564578d8f845813483352802a9.js"></script>
# <script>
# $j(document).ready(function(){
# offcanvas();
# });
# var offcanvas = function() {
# var $clone = $j('#fh5co-menu-wrap').clone();
# $clone.attr({
# 'id' : 'offcanvas-menu'
# });
# $clone.find('> ul').attr({
# 'class' : '',
# 'id' : ''
# });
# $j('#fh5co-page').prepend($clone);
# // click the burger
# $j('.js-fh5co-nav-toggle').on('click', function(){
# if ( $j('body').hasClass('fh5co-offcanvas') ) {
# $j('body').removeClass('fh5co-offcanvas');
# } else {
# $j('body').addClass('fh5co-offcanvas');
# }
# // event.preventDefault();
# });
# $j('#offcanvas-menu').css('height', $j(window).height());
# $j(window).resize(function(){
# var w = $j(window);
# $j('#offcanvas-menu').css('height', w.height());
# if ( w.width() > 769 ) {
# if ( $j('body').hasClass('fh5co-offcanvas') ) {
# $j('body').removeClass('fh5co-offcanvas');
# }
# }
# });
# }
# // Click outside of the Mobile Menu
# var mobileMenuOutsideClick = function() {
# $j(document).click(function (e) {
# var container = $j("#offcanvas-menu, .js-fh5co-nav-toggle");
# if (!container.is(e.target) && container.has(e.target).length === 0) {
# if ( $j('body').hasClass('fh5co-offcanvas') ) {
# $j('body').removeClass('fh5co-offcanvas');
# }
# }
# });
# };
# </script>
# </head>
# <body>
# <div id="fh5co-wrapper">
# <div id="fh5co-page">
# <nav id="offcanvas-menu" role="navigation" style="height: 901px;">
# <ul class="" id="" style="touch-action: pan-y;">
# <li class="active">
# <a href="/alert.html"><i class="icon-bell-alt"></i> Alerts</a>
# </li>
# <li class="">
# <a href="/questions.html">Learn More</a>
# </li>
# <li class="">
# <a href="/contact.html">Contact</a>
# </li>
# <li>
# <a href="https://mls.foreclosure.com/login.html">Sign In</a>
# </li>
# <li>
# <a href="/registration.html" class="green-btn headerBtn">Get Free Trial</a>
# </li>
# </ul>
# </nav>
# <div class="sticky-wrapper" style="height: 107px;">
# <header id="fh5co-header-section" class="sticky-banner stuck">
# <div class="container">
# <div class="nav-header">
# <a href="#" class="js-fh5co-nav-toggle fh5co-nav-toggle dark"><i></i></a>
# <h1 id="fh5co-logo"><a href="http://www.mls.com/"><img style="width: 176px; height: 42px;" src="//dlvp94zy6vayf.cloudfront.net/static/css/cobrands/mls/mls_logo-78f50000b9bad0793cf75e320e633cb5.png" alt="logo"></a></h1>
# <!-- START #fh5co-menu-wrap -->
# <nav id="fh5co-menu-wrap" role="navigation">
# <ul class="sf-menu sf-js-enabled sf-arrows" id="fh5co-primary-menu" style="touch-action: pan-y;">
# <li class="active">
# <a href="/alert.html"><i class="icon-bell-alt"></i> Alerts</a>
# </li>
# <li class="">
# <a href="/questions.html">Learn More</a>
# </li>
# <li class="">
# <a href="/contact.html">Contact</a>
# </li>
# <li>
# <a href="https://mls.foreclosure.com/login.html">Sign In</a>
# </li>
# <li>
# <a href="/registration.html" class="green-btn headerBtn">Get Free Trial</a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# </header>
# </div>
# <div id="fh5co-features" class="fh5co-section-gray">
# <div class="container mainWrapContainer">
# <div class="row">
# <div class="col-lg-12" style="padding-bottom:10px;">
# <div class="pull-right">
# <a href="https://mls.foreclosure.com/login.html" class="btn btn-default btn-outline-primary btn-xs">Login</a> <a href="/registration.html" class="btn btn-default btn-outline-primary btn-xs">Free Trial</a>
# </div>
# <div class="pull-left">
# <div class="breadcrumb" id="breadcrumbMain"><a href="https://mls.foreclosure.com/" title="foreclosures" alt="foreclosures" >Home</a>&nbsp;/&nbsp;<a href="/state/tx" >Texas </a>&nbsp;/&nbsp;<a href="/listings/travis-county-tx/" >Travis County</a>&nbsp;/&nbsp;Listing Details </div>
# </div>
# </div>
# </div>
#
#
# <div id="bootstrap-details" class="hidden-print">
# <div class="row">
# <div class="col-md-8">
# <div id="fixed-details" class="row main-details">
# <div class="col-sm-9">
# <div class="pull-left">
# <h3 class="address">
# <span style="white-space:nowrap"><a rel="nofollow" href="/registration.html?listingid=61742859" style="font-weight: normal;">Click for complete address</a></span>
# </h3>
# <h1 style="margin-top: 0px;" class="region">
# <span>Austin, TX 78721</span>
# </h1>
# <h4>
# </h4>
# </div>
# </div>
# <div class="col-sm-3">
# <div class="clearfix"></div>
# <div class="text-right left-xs">
# <h3 class="text-right left-xs price">&nbsp;</h3>
# </div>
# <div class="text-right left-xs">
# <div><small>Status:</small> Active</div>
# <div><small>Listing ID:</small> 61742859</div>
# </div>
# </div>
# </div>
# <div id="tab_container">
# <div role="tabpanel" class="hidden-xs tabdetails-false">
# <ul class="nav nav-tabs nav-justified" id="details_tabs" role="tablist">
# <li id="details_main_tab" class="details_tab current active" alt="main_tab_content" role="presentation"><a href="#tab-main" data-toggle="tab"><i class="icon-picture"></i> Photos (0)</a></li>
# <li id="details_map_tab" class="details_tab" alt="map_tab_content" role="presentation"><a href="#tab-map" data-mode="map" data-toggle="tab"><i class="icon-map-marker"></i> Map</a></li>
# </ul>
# </div>
# <div id="main_tab_content" class="tab-content">
# <div class="tab-pane active" id="tab-main" role="tabpanel">
# <div id="photo_container_notLoggedIn" style='background: url("https://dlvp94zy6vayf.cloudfront.net/listingphoto/KZTU6NBYPBJHAWDMN5TGCMLYMEWVQRBYOFRHKSC2IRPUE3CHM5VVIWRQOFMWESDVOJZGG===.jpg") center center no-repeat; background-size: cover;'>
# <div class="unknownDealsContent">
# <h2 style="margin: 12% 10% 20px; text-align: center;font-size: 35px;">Interested in this property?</h2>
# <a rel="nofollow" href='/registration.html?listingid=61742859' class="btn btn-secondary btn-lg" cmp-clk="registrationButton" id="view-more-photos">View More Photos</a>
# </div>
# <script type="text/javascript">
# $j(window).load( function(){
# // hide photos tab
# $j('#details_photo_tab').remove();
# $j('#morePhotos').attr('src', '/static/css/cobrands/bootstrap_cobrand/img/moremaps_responsive.jpg');
# });
# </script>
# </div>
# </div> <div class="tab-pane" id="tab-map" role="tabpanel">
# <div id="large_map_containerNotLoggedIn">
# <div class="unknownDealsContent">
# <h1 style="margin: 20% 10% 20px; text-align: center;font-size: 30px;">Want to see full property details?</h1>
# <a rel="nofollow" href='/registration.html?listingid=61742859' class="btn btn-primary btn-lg">Get FREE Preview Now!</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-4">
# <script type="text/javascript" src="//dlvp94zy6vayf.cloudfront.net/static/lib/jquery-validation-1.9.0/jquery.validate.min.js"></script>
# <script type="text/javascript">
# $j(function() {
# q = "q=78721";
# $j.getJSON("/listing/search/ui/event?_savesearch=false", q, getResults).error(function(){ });
# $j("#page1submit").on("click", function(e) {
# $j("#error").html("");
# if($j("#page1form").valid()){
# createAccount("page1form");
# $j("#page1submit").attr("disabled","disabled");
# }else{
# $j("#page1form").submit();
# }
# e.preventDefault();
# });
# jQuery.extend(jQuery.validator.messages, {
# required: "Required."
# });
# $j.validator.addMethod("invalidCharacters", function(value, element, params){
# var valid = true;
# for(var i = 0; i < params.length; i++){
# var nextChar = params.charAt(i);
# if(value.indexOf(nextChar) >= 0){
# valid = false;
# break;
# }
# }
# return this.optional(element) || valid;
# }, "Invalid characters.");
# page1Validator = $j('#page1form').validate(
# {
# errorPlacement: function(error, element){
# var field = element.attr("name");
# error.appendTo($j("#error-"+field));
# $j("#error-"+field).parent().show()
# },
# success: function(label){
# var labelParent = label.parent();
# $j(label).remove();
# siblingErrors = false;
# $j(labelParent.siblings()).each(function(i,item){
# if( $j(item).children().length ){
# siblingErrors = true;
# }
# });
# if(!siblingErrors){
# labelParent.parent().hide();
# }
# },
# rules : {
# "email": {
# required: true,
# email: true
# },
# "password":{
# required: true,
# minlength: 8,
# invalidCharacters: "\"'"
# },
# emailConfirm: {
# equalTo: '#emailField'
# }
# },
# messages : {
# "password" : {
# minlength: "Password must be a minimum of 8 characters.",
# invalidCharacters: 'Invalid Characters. The following characters are not valid: \"\''
# },
# emailConfirm:{
# equalTo: "Email does not match - Please review & update"
# }
# }
# }
# );
# });
# function getResults(data){
# var results = data.results;
# var idx = 0;
# if(results.length == 0){
# $j('#foreclosureCarousel').parent().hide();
# }
# if(results.length < 6){
# $j('#resultsContainer2').parent().remove();
# }
# if(results.length < 12){
# $j('#resultsContainer3').parent().remove();
# }
# for(var i = 0; i < results.length; i++){
# var record = results[i];
# var temp = $j('#searchResultItemTemplate').clone();
# var photoUrl = '//dlvp94zy6vayf.cloudfront.net/listingphoto/' + record.photoCipher + '.jpg';
# temp.find('.item_photo').attr('src', photoUrl);
# temp.find('.item_price').html(record.price);
# temp.find('.item_address').html('<div class="street">' + record.street +"</div> <small>"+record.city + ", " + record.state + " " + record.zip + "</small>").attr('title', record.street + record.city + record.state);
# temp.find('.item_beds').html(record.beds);
# temp.find('.item_baths').html(record.baths);
# if(record.size){
# temp.find('.item_sqft').html(numberWithCommas(record.size) + " sq. ft.");
# }
# temp.find('.item_link').attr('href', record.detailsPageLink);
# if(i < 6){
# temp.attr("id", "record_" +record. listingId).appendTo('#resultsContainer1').show();
# } else if(i < 12){
# temp.attr("id", "record_" +record. listingId).appendTo('#resultsContainer2').show();
# }else if(i < 18){
# temp.attr("id", "record_" +record. listingId).appendTo('#resultsContainer3').show();
# }
# idx++;
# if(i > 18){
# return false;
# }
# }
# }
# function numberWithCommas(x) {
# return x.toString().replace(/\B(?=(\d{3})+(?!\d))/g, ",");
# }
# var loggedOn= false;
# var page1Validator = null;
# var saveAlert = function(username, password){
# var loc = $j("#loc").val();
# var alertObj = {name: loc.trim(), searchParams: "loc="+loc.trim(), period: "DAILY", frequency: 1};
# var ajaxReq = {
# 'type': 'POST',
# 'url': '/rest_api/search/alert',
# 'contentType': 'application/json',
# 'data': JSON.stringify(alertObj),
# 'success': function(data) {
# if(typeof(gtag) != "undefined"){
# gtag('event', 'Click', {'event_category' : 'CreateAlert', 'event_label' : 'ListingDetails'});
# }
# window.setTimeout(function() { window.location="/start.html"; }, 800);
# },
# 'statusCode': {
# 401: function() {
# window.location.pathname = '/login';
# },
# 404: function() {
# alert("Unable to process Request");
# },
# },
# 'error': function(ejqXHR, textStatus, errorThrown) {
# },
# 'dataType': 'json'
# }
# if (arguments.length == 2) {
# ajaxReq['headers'] = {
# "Authorization": "Basic " + btoa(username + ":" + password)
# }
# var jqXHR = $j.ajax(ajaxReq);
# } else {
# $j.ajax(ajaxReq);
# }
# }
# var createAccount = function(){
# var hashtable = {};
# $j("#page1form :input.account").each(function( index ) {
# if($j(this).attr("name") == "opt_in"){
# hashtable[$j( this ).attr('name')] = $j( this ).is(':checked');
# }else{
# hashtable[$j( this ).attr('name')] = $j( this ).val();
# }
# });
# var jdata =JSON.stringify(hashtable);
# $j.ajax({
# type: 'POST',
# url: '/subscriptions',
# data: jdata,
# error: function(data) {
# var obj = jQuery.parseJSON(data.responseText);
# $j("#error").html(obj['errorMessage']);
# $j("#errorPlaceholder").show();
# $j("#page1submit").removeAttr("disabled");
# },
# success: function(data) {
# $j("#errorPlaceholder").hide();
# var obj = jQuery.parseJSON(JSON.stringify( data ));
# if(typeof(gtag) != "undefined"){
# gtag('event', 'Click', {'event_category' : 'subscriptionsListingDetails1Success', 'event_label' : 'subscriptions'});
# }
# $j("#accountId").val(obj['accountId']);
# var username = $j("#page1form input[name='email']").val();
# var password = $j("#page1form input[name='password']").val();
# $j.ajax({
# url: "/subscriptions/login",
# type: "POST",
# beforeSend: function(xhr){
# xhr.setRequestHeader("Authorization", "Basic " + btoa(username + ":" + password));
# xhr.setRequestHeader("Accept", "application/json");
# },
# success: function () {
# if ( $j('#alert').is(':checked') ) {
# saveAlert(username, password);
# }else{
# // go to Subcription page
# window.setTimeout(function() { window.location="/start.html"; }, 800);
# }
# },
# statusCode: {
# 401:function() { window.location.pathname = '/login'; },
# 404:function() { alert("Unable to process Request"); },
# }
# });
# },
# contentType: "application/json",
# dataType: 'json'
# });
# }
# if (!window.btoa) {
# // Source: http://www.koders.com/javascript/fid78168FE1380F7420FB7B7CD8BAEAE58929523C17.aspx
# btoa = function (input) {
# var chars = 'ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789+/=';
# var result = '';
# var chr1, chr2, chr3;
# var enc1, enc2, enc3, enc4;
# var i = 0;
# do {
# chr1 = input.charCodeAt(i++);
# chr2 = input.charCodeAt(i++);
# chr3 = input.charCodeAt(i++);
# enc1 = chr1 >> 2;
# enc2 = ((chr1 & 3) << 4) | (chr2 >> 4);
# enc3 = ((chr2 & 15) << 2) | (chr3 >> 6);
# enc4 = chr3 & 63;
# if (isNaN(chr2)) {
# enc3 = enc4 = 64;
# } else if (isNaN(chr3)) {
# enc4 = 64;
# }
# result += chars.charAt(enc1) + chars.charAt(enc2) + chars.charAt(enc3) + chars.charAt(enc4);
# } while (i < input.length);
# return result;
# };
# }
# $j( document ).ready(function() {
# $j("#emailConfirmField").hide();
# $j('#firstNameField').on('click touchend focus',function(){
# $j("#emailConfirmField").show();
# });
# });
# </script>
# <style>
# #registration_pg1_container{ margin-top: 25px;}
# #registration_pg1_container #errorPlaceholder { display: none; }
# #registration_pg1_container .alert-error{ margin-bottom: 10px; }
# #registration_pg1_container .error{margin:0;}
# #registration_pg1_container label.error {display:block; font-weight: normal; color: #f55a53; font-size:12px; padding:0 0 5px; margin:0px; background:none; border:none; }
# #registration_pg1_container .error-container { padding: 0px; }
# #registration_pg1_container .input-group-multifield{ background-color:#fefeff;}
# #registration_pg1_container .form-collapsed .form-group { margin-top: 15px; margin-bottom: 0px; }
# #registration_pg1_container .form-collapsed .form-group select{ color: #888; -moz-appearance: none; -webkit-appearance: none; }
# #registration_pg1_container .form-collapsed .form-group .form-control {display:block; border-radius: 0px; border: 0px none; padding-left:5px; background-color:transparent; z-index:2;}
# #registration_pg1_container .form-collapsed .form-group .input-group-multifield { clear:both; }
# #registration_pg1_container .form-collapsed .form-group .input-group-multifield div { border-left: 0px none; border-right: 1px solid #ccc; border-top: 1px solid #ccc; border-bottom: 0px none; }
# #registration_pg1_container .form-collapsed .form-group .input-group-multifield div:first-child { border-left:1px solid #ccc; }
# #registration_pg1_container .form-collapsed .form-group .input-group-multifield { display: block; separate; float:none; clear:both; z-index:1; position: relative; min-height:34px; }
# #registration_pg1_container .form-collapsed .form-group .input-group-multifield .form-control{ border-collapse: separate; position: relative; z-index:2;}
# #registration_pg1_container .form-collapsed .form-group .input-group-multifield:first-child div:first-child { border-top-left-radius: 4px; }
# #registration_pg1_container .form-collapsed .form-group .input-group-multifield:first-child div:last-child { border-top-right-radius: 4px; }
# #registration_pg1_container .form-collapsed .form-group .input-group-multifield:last-child div:first-child,
# #registration_pg1_container .form-collapsed .form-group .input-group-multifield.last div:first-child{ border-bottom-left-radius: 4px; border-bottom: 1px solid #ccc; border-left: 1px solid #ccc;}
# #registration_pg1_container .form-collapsed .form-group .input-group-multifield:last-child div,
# #registration_pg1_container .form-collapsed .form-group .input-group-multifield.last div{ border-bottom-right-radius: 0px; border-bottom: 1px solid #ccc; }
# #registration_pg1_container .form-collapsed .form-group .input-group-multifield:last-child div:last-child,
# #registration_pg1_container .form-collapsed .form-group .input-group-multifield.last div:last-child { border-bottom-right-radius: 4px; border-bottom: 1px solid #ccc; }
# #registration_pg1_container .form-collapsed .form-group .form-control:focus { box-shadow: 0 1px 1px rgba(0, 0, 0, 0.075) inset, 0 0 8px rgba(102, 175, 233, 0.6); z-index:10; }
# #registration_pg1_container .form-collapsed .form-group .form-control.error:focus { box-shadow: 0 0 8px rgba(204, 46, 46, 1);}
# #registration_pg1_container .form-collapsed .form-group .input-group-multifield .form-control{ border-radius: 0; padding-left: 12px; }
# #registration_pg1_container .form-collapsed .form-group .input-group-multifield .col-xs-12{ padding:0px; width: 100% }
# #registration_pg1_container .form-collapsed .form-group .input-group-multifield .col-xs-6{ padding:0px; width: 50% }
# #registration_pg1_container .form-collapsed .form-group .input-group-multifield .col-xs-5{ padding:0px; width: 41.6667% }
# #registration_pg1_container .form-collapsed .form-group .input-group-multifield .col-xs-4{ padding:0px; width: 33.3333% }
# #registration_pg1_container .form-collapsed .form-group .input-group-multifield .col-xs-3{ padding:0px; width: 25% }
# #registration_pg1_container .form-collapsed .form-group .input-group-multifield .col-xs-2{ padding:0px; width: 16.6667% }
# #registration_pg1_container .form-collapsed .form-group .error-group-multifield { border-top: 1px solid #ccc; }
# #registration_pg1_container .form-collapsed .form-group .error-group-multifield.last { border-top:0px none; }
# #registration_pg1_container input[type=number]::-webkit-outer-spin-button,
# #registration_pg1_container input[type=number]::-webkit-inner-spin-button { -webkit-appearance: none; margin: 0; }
# #registration_pg1_container input[type=number] { -moz-appearance:textfield; }
# #registration_pg1_container [class^="iconbg-"] { padding-left:35px !important; background-position: 5px 50%; background-repeat: no-repeat;}
# #registration_pg1_container .iconbg-input-email{ background-image: url(/static/css/cobrands/fdc/img/icon_input_email2.png);}
# #registration_pg1_container .iconbg-input-password { background-image: url(/static/css/cobrands/fdc/img/icon_input_password2.png);}
# #registration_pg1_container .iconbg-input-name { background-image: url(/static/css/cobrands/fdc/img/icon_input_name2.png);}
# #registration_pg1_container .btn-secondary:hover {
# background-color: #056839;
# color: #fff;
# }
# @media(min-width:760px){
# #registration_pg1_container #registration_pg1_container .registration_pg_wrapper { padding: 40px 0px; }
# #registration_pg1_container #registration_pg2_container .registration_pg_wrapper { padding: 10px 40px; }
# }
# </style>
# <div id="registration_pg1_container">
# <div class="row">
# <div class="col-md-12 well">
# <div class="registration_pg_wrapper">
# <div class="row">
# <div class="col-sm-12">
# <h4 style="font-weight:600; margin-top: 0px; font-size: 20px;" class="text-center">Create a Free Account</h4>
# </div>
# </div>
# <div id="errorPlaceholder" class="row">
# <div class="col-sm-12">
# <div class="alert-error">
# <div id="error"></div>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col-sm-12">
# <form id="page1form" class="form form-collapsed" method="post">
# <div class="form-group">
# <div class="input-group-multifield">
# <div class="col-xs-6">
# <input id="firstNameField" type="text" name="first_name" class="iconbg-input-name form-control account required" placeholder="First Name">
# </div>
# <div class="col-xs-6">
# <input type="text" name="last_name" class="form-control account required" placeholder="Last Name">
# </div>
# </div>
# <div class="error-group-multifield" style="display:none;">
# <div class="col-xs-6" id="error-first_name"></div>
# <div class="col-xs-6" id="error-last_name"></div>
# </div>
# <div class="input-group-multifield">
# <div class="col-xs-12">
# <input id="emailField" type="email" name="email" class="iconbg-input-email form-control account required" placeholder="Email">
# </div>
# </div>
# <div class="error-group-multifield" style="display:none;">
# <div class="col-xs-12" id="error-email"></div>
# </div>
# <div id="emailConfirmField" class="input-group-multifield">
# <div class="col-xs-12">
# <input type="email" name="emailConfirm" class="iconbg-input-email form-control account required" placeholder="Confirm Email">
# </div>
# </div>
# <div class="error-group-multifield" style="display:none;">
# <div class="col-xs-12" id="error-emailConfirm"></div>
# </div>
# <div class="input-group-multifield last">
# <div class="col-xs-12">
# <input type="password" name="password" class="iconbg-input-password form-control account required" placeholder="Create Password">
# </div>
# </div>
# <div class="error-group-multifield last" style="display:none;">
# <div class="col-xs-12" id="error-password"></div>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="checkbox small">
# <label style="font-size: 9px;">
# <input type="checkbox" name="alert" id="alert" class="account" checked style="margin-top: 0px;" /> Email me when new homes are listed in
# Austin, TX
# <input type="hidden" name="loc" class="account" value="Austin, TX" id="loc" />
# </label>
# </div>
# <div class="checkbox small">
# <label style="font-size: 9px;" class="text-justify">
# <input type="checkbox" name="opt_in" class="account" checked style="margin-top: 0px;" /> By checking this box, I have read the <a href="/terms.html" target="_blank">Terms and Conditions of Service</a> and agree to receive emails from mls.foreclosure.com.
# </label>
# </div>
# <div class="form-group">
# <button id="page1submit" type="submit" class="btn btn-secondary btn-block">Get Started</button>
# </div>
# <input type="hidden" name="service_offering_name" value="default1Month" class="account" />
# <input type="hidden" name="type" value="two_page_registration" class="account" />
# </form>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12 nearbyHomes">
# <hr />
# <h4>Nearby Homes</h4>
# <div class="carousel slide" id="foreclosureCarousel" data-interval="false">
# <div class="carousel-inner">
# <div class="item active">
# <ul class="thumbnails" id="resultsContainer1"></ul>
# </div>
# <div class="item">
# <ul class="thumbnails" id="resultsContainer2"></ul>
# </div>
# <div class="item">
# <ul class="thumbnails" id="resultsContainer3"></ul>
# </div>
# </div>
# <a class="left carousel-control" href="#foreclosureCarousel" role="button" data-slide="prev">
# <span class="glyphicon glyphicon-chevron-left" aria-hidden="true"></span>
# <span class="sr-only">Previous</span>
# </a>
# <a class="right carousel-control" href="#foreclosureCarousel" role="button" data-slide="next">
# <span class="glyphicon glyphicon-chevron-right" aria-hidden="true"></span>
# <span class="sr-only">Next</span>
# </a>
# </div>
# </div>
# <li class="col-sm-2 col-xs-6" id="searchResultItemTemplate" style="display:none;">
# <div class="fff">
# <div class="thumbnail">
# <a href="#" class="item_link"><img src="" class="item_photo img-responsive" height="100" width="150" ></a>
# </div>
# <div class="caption">
# <h5><a href="#" class="item_link"><span class="item_address">Sw 100th Ave <br />Miami, FL 33176</span></a></h5>
# <h4 class="item_price"></h4>
# <p><span class="item_beds">-</span> bds • <span class="item_baths">-</span> ba <br /> <span class="item_sqft"></span></p>
# </div>
# </div>
# </li>
# <div class="col-md-8">
# <div id="additional_info">
# <h3>Property Information</h3>
# <ul class="list-unstyled attributegroup two-column">
# <li class="even details_li_source_id softincpre">
# <span class="attr-label details_span_source_id">Source ID:</span>
# <a rel="nofollow" href="/registration.html?listingid=61742859" alt="Join now for details" title="Join now for details" class="three registrationPage" cmp-imp="softincpre_source_id_details_attribute" cmp-clk="softincpre_source_id_details_attribute">Join now for details</a>
# </li>
# <li class="details_li_day(s)_on_site softincpre">
# <span class="attr-label details_span_day(s)_on_site">Day(s) On Site:</span>
# <a rel="nofollow" href="/registration.html?listingid=61742859" alt="Join now for details" title="Join now for details" class="three registrationPage" cmp-imp="softincpre_day(s)_on_site_details_attribute" cmp-clk="softincpre_day(s)_on_site_details_attribute">Join now for details</a>
# </li>
# <li class="even details_li_plaintiff softincpre">
# <span class="attr-label details_span_plaintiff">Plaintiff:</span>
# <a rel="nofollow" href="/registration.html?listingid=61742859" alt="Join now for details" title="Join now for details" class="three registrationPage" cmp-imp="softincpre_plaintiff_details_attribute" cmp-clk="softincpre_plaintiff_details_attribute">Join now for details</a>
# </li>
# <li class="details_li_case_number softincpre">
# <span class="attr-label details_span_case_number"><span class="defined handcursor" title="cssbody=[tipbdy1] cssheader=[tiphdr1] header=[Case Number] body=[The lender's file reference number used by the attorney to designate the property.] delay=[0] fadespeed=[0.4] fade=[on]">Case Number</span>:</span>
# <a rel="nofollow" href="/registration.html?listingid=61742859" alt="Join now for details" title="Join now for details" class="three registrationPage" cmp-imp="softincpre_case_number_details_attribute" cmp-clk="softincpre_case_number_details_attribute">Join now for details</a>
# </li>
# <li class="even details_li_recording_date softincpre">
# <span class="attr-label details_span_recording_date">Recording Date:</span>
# <a rel="nofollow" href="/registration.html?listingid=61742859" alt="Join now for details" title="Join now for details" class="three registrationPage" cmp-imp="softincpre_recording_date_details_attribute" cmp-clk="softincpre_recording_date_details_attribute">Join now for details</a>
# </li>
# <li class="details_li_deed_category softincpre">
# <span class="attr-label details_span_deed_category">Deed Category:</span>
# <a rel="nofollow" href="/registration.html?listingid=61742859" alt="Join now for details" title="Join now for details" class="three registrationPage" cmp-imp="softincpre_deed_category_details_attribute" cmp-clk="softincpre_deed_category_details_attribute">Join now for details</a>
# </li>
# <li class="even details_li_document_number softincpre">
# <span class="attr-label details_span_document_number">Document Number:</span>
# <a rel="nofollow" href="/registration.html?listingid=61742859" alt="Join now for details" title="Join now for details" class="three registrationPage" cmp-imp="softincpre_document_number_details_attribute" cmp-clk="softincpre_document_number_details_attribute">Join now for details</a>
# </li>
# <li>&nbsp;</li>
# </ul>
# <div class="description">
# <h3>Preforeclosure</h3>
# Often, the preforeclosure period is the best time to purchase a property. The process begins when a lender first notifies a borrower that his or her loan payments are behind. If a borrower has no other means to bring the payments up to date, he or she is far better served to sell the property as soon as possible before it falls into foreclosure.
# </div>
# <ul class="list-unstyled attributegroup" id="attributegroup_county_information" >
# <h3> County Information</h3>
# <li class="even details_li_county_site oneline_details_li softincpre">
# <span class="attr-label details_span_county_site">County Site:</span>
# <a rel="nofollow" href="/registration.html?listingid=61742859" alt="Join now for details" title="Join now for details" class="registrationPage" cmp-imp="softincpre_county_site_details_attribute" cmp-clk="softincpre_county_site_details_attribute">Join now for details</a>
# </li>
# <li class="details_li_county_appraiser_site oneline_details_li softincpre">
# <span class="attr-label details_span_county_appraiser_site">County Appraiser Site:</span>
# <a rel="nofollow" href="/registration.html?listingid=61742859" alt="Join now for details" title="Join now for details" class="registrationPage" cmp-imp="softincpre_county_appraiser_site_details_attribute" cmp-clk="softincpre_county_appraiser_site_details_attribute">Join now for details</a>
# </li>
# </ul>
# <div></div>
# <ul class="sortableattributegroups">
# </ul>
# <script type="text/javascript">
# function showMe(p){
# document.getElementById(p).style.display='block';
# document.getElementById('readmore').style.display='none';
# }
# function displayMe(p){
# document.getElementById(p).style.display='none';
# document.getElementById('readmore').style.display='block';
# }
# </script>
# <a name="firststep"></a>
# <table class="steps">
# <tr>
# <td>
# <h1>FIRST STEPS:</h1>
# <span>Preforeclosures</span><br />
# <p>Often, the preforeclosure period is the best time to purchase a property.</p>
# <p id="readmore"><a href="#firststep" onclick="showMe('hideme');">Read more</a></p>
# <div id="hideme">
# <p>Preforeclosure begins when a lender first notifies a borrower that his or her loan payments are behind. This
# notification also details the consequences that occur if payments, penalties and interest are not brought current.</p>
# <p>In most cases, a foreclosure severely limits a borrowers future credit options. Therefore, if a borrower has no
# other means to bring the payments up to date, he or she is far better served to sell the property rather than to
# let it go into foreclosure.</p>
# <p>If you're interested in the property, contact the borrower/owner as soon as possible. For your convenience, this contact information is located under the property's "Foreclosure Information" header.</p>
# <p>Carefully explain that you can help him or her avoid foreclosure by purchasing their home before it is lost to the lender.</p>
# <p>Your timely assistance can be very important. But, be sensitive to the difficulties they are facing and be prepared to close quickly.</p>
# <p id="close"><a href="#firststep" onclick="displayMe('hideme');">Close</a></p>
# </div>
# </td>
# </tr>
# </table>
# <div id="calculators_container">
# <h3 id="calculators">Learning Center</h3>
# <ul class="list-unstyled">
# <li id="icon_tools_buyforclosurehome" class="alltools_nowrap">
# <a href="/stateprocedure_TX.html" title="How to buy foreclosure homes in Texas">How to buy foreclosure homes in
# Texas
# </a>
# </li>
# <li id="icon_tools_foreclosurelaws">
# <a href="/statelaw_TX.html" title="Texas foreclosure laws">
# Texas
# foreclosure laws</a>
# </li>
# <li id="icon_tools_bankruptcylaw"><a href="/bankruptcylaw.html?st=TX&pg=1" title="Bankruptcy law in Texas">Bankruptcy law</a></li>
# <li id="icon_tools_glossary"><a href="/glossary.html?i=a&st=TX" title="Glossary & terms">Glossary & terms</a></li>
# <li id="icon_tools_blog"><a href="https://www.foreclosure.com/articles/" target="_blank" title="Foreclosure Listings, Articles and News">Foreclosure Listings, Articles and News</a></li>
# </ul>
# </div>
# <hr>
# <p>The information provided on the Website, which encompasses details such as property dimensions, floor area, valuation, geographic location, and general property description, is furnished for your convenience and originates from third-party sources. This data should not be interpreted as constituting a contractual offer for the procurement, leasing, or advertising of real estate. No express or implied warranties or assurances are extended concerning these properties, including their availability. While the data presented on this Website is considered reliable, it acknowledges a degree of uncertainty, thus necessitating independent verification.</p>
# <p>The administrators of this platform, as well as their respective directors, associates, and personnel, have not undertaken a process of due diligence to verify the accuracy of the information. Their role is limited to disseminating the information, and they do not accept liability, whether direct or indirect, for any injuries, losses, claims, damages, or associated indirect or consequential harms, including but not limited to lost profits or savings, arising from the use of any information or any deficiencies, inaccuracies, or defects in the disseminated information within the bounds of the Website.</p>
# <p>mls.foreclosure.com, in conjunction with its Affiliates, disclaims any responsibility arising from your acquisition of third-party goods, services, or tangible properties based on the informational context of the Site. mls.foreclosure.com reserves the right, at its sole discretion and without prior notice, to rectify errors or omissions within any section of the Site or to restrict access to the Site.</p>
# <p>Relying solely on the informational content featured on the Website is not advisable. Conduct your own personal inquiries and seek legal counsel regarding any property under consideration within the scope of the Website or the associated data.</p>
# </div>
# </div> <div class="col-md-4">
# <div id="rightrail_container">
# <div class="ad_wrapper">
# <div class="ad300x250 vp_1">
# <script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- FDC_Details300x250 -->
# <ins class="adsbygoogle"
# style="display:inline-block;width:300px;height:250px"
# data-ad-client="ca-pub-4034915303871713"
# data-ad-slot="8466887327"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </div>
# </div>
# <div class="ad_wrapper">
# <div class="ad300x250 vp_1">
# <!-- FDC_Details300x250 -->
# <ins class="adsbygoogle"
# style="display:inline-block;width:300px;height:250px"
# data-ad-client="ca-pub-4034915303871713"
# data-ad-slot="8466887327"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="container visible-print-block">
# <div class="row">
# <div class="col-sm-6">
# <img src="//dlvp94zy6vayf.cloudfront.net/static/css/cobrands/fdc/img/big-fdc-logo-print-f8a6264f13df20b3ebda402031729639.png" class="logoBig" width="155" height="43" alt="foreclosure.com" itemprop="contentUrl"/>
# </div>
# <div class="col-sm-6">
# <div class="text-right"></div>
# </div>
# </div>
# <div class="row">
# <div class="col-sm-7">
# <div class="pull-left">
# <h3 class="address">
# <span style="white-space:nowrap">Ed Bluestein Blvd</span><br/>
# <span style="white-space:nowrap">Austin, TX 78721</span>
# </h3>
# <h4>
# </h4>
# <h3>&nbsp;</h3>
# <h4 style="white-space:nowrap;">
# <small>Status:</small> Active
# <small style="margin-left: 20px;">Listing ID:</small> 61742859
# </h4>
# </div>
# </div>
# <div class="col-sm-3" style="float:right; width:40%;">
# </div>
# </div>
# <div class="row">
# <div class="col-sm-12">
# <h3>Property Information</h3>
# <div>Sign in to see detailed property information.</div>
# </div>
# <div class="col-sm-12">
# <h3>Public Records</h3>
# <div>Sign in to see detailed property information.</div>
# </div>
# <div class="col-sm-12">
# <h3>Property Description</h3>
# <div>Sign in to see detailed property information.</div>
# </div>
# <div class="col-sm-12">
# <h3>Listing URL</h3>
# https://mls.foreclosure.com/listing/address.html?address=Ed-Bluestein-Blvd-Austin-TX-78721/61742859_lid
# </div>
# </div>
# </div>
# <div style="display:none;">
# <div id="confirmDeleteDialog" class="bd" style="width: 375px;">
# <form name="dialogForm" action="/provisioning/profile/my_listingnotes.html" method="POST">
# <input type="hidden" name="listingId" id="deleteListingId"/>
# <p id="dialogMssg"></p>
# <input type="checkbox" name="dontAsk" value="1" id="dontaskcheckbox" /><label for="dontAsk" style="font-size: 12px;">Don't ask me again</label>
# <div style="padding: 4px;">
# <input class="btn btn-default" type="button" onclick="$j.fancybox.close();return false;" value="Cancel"/>
# <input class="btn btn-primary" type="button" onclick="handleRemove(); return false;" value="Remove" style="margin-left:10px;"/>
# </div>
# </form>
# </div>
# </div>
# <link rel="stylesheet" href="//dlvp94zy6vayf.cloudfront.net/static/lib/bower_components/leaflet/dist/leaflet-508a9152edee29484ed209845c60b3e9.css" />
# <script src="//dlvp94zy6vayf.cloudfront.net/static/lib/bower_components/leaflet/dist/leaflet-57ff70669f76ceeaa710f1064387fa14.js"></script>
# <script src="//dlvp94zy6vayf.cloudfront.net/static/lib/bower_components/Leaflet.label/dist/leaflet.label-src-5a1da449592dcc0fc95de7f26222d97c.js"></script>
# <script type="text/javascript" src="//dlvp94zy6vayf.cloudfront.net/static/css/cobrands/bootstrap_cobrand/js/mapdetails-517c22e17c1064540144dfc42d581f6a.js"></script>
#
#
# <div class="boxfooter">
# <div style="LINE-HEIGHT: 1px; BACKGROUND-COLOR: #cccccc; margin-bottom: 20px; font-size: 2px;">&nbsp;</div>
# &copy; <a href="https://www.foreclosure.com" style="text-decoration: none;">Foreclosure.com.</a> 1999-2024. All Rights Reserved.<br />
# <div style="margin-bottom: 10px;"><span style="vertical-align:-12px;">Service by</span> <a href="https://www.foreclosure.com"><img src="//dlvp94zy6vayf.cloudfront.net/static/css/img/FDC_logo_109x30-93d8fad80ef25c8ba28ca11651b9cba4.png" align="top"></a></div>
# </div>
# </div>
# </div>
# <footer>
# <div id="footer">
# <div class="container">
# <div class="row row-bottom-padded-md">
# <div class="col-md-2 col-sm-4 col-xs-6 fh5co-footer-link">
# <h3>Company</h3>
# <ul>
# <li><a href="http://www.mls.com/Home/About.mvc">About Us</a></li>
# <li><a href="http://www.mls.com/Home/Contact.mvc">Contact Us</a></li>
# <li><a href="/login?referralUrl=/provisioning/account/account.html">Cancel Service</a></li>
# <li><a href="http://www.mls.com/Home/PrivacyPolicy.mvc">Privacy Policy</a></li>
# <li><a href="http://www.mls.com/Home/TermsOfUse.mvc">Terms of Use</a></li>
# <li><a href="http://www.mls.com/Sitemap.html">Site Map</a></li>
# </ul>
# </div>
# <div class="col-md-2 col-sm-4 col-xs-6 fh5co-footer-link">
# <h3>Property Search</h3>
# <ul>
# <li><a href="http://www.mls.com/ForeclosureListings/">Find Foreclosures</a></li>
# <li><a href="http://www.newhomesource.com/mls_com" target="_blank">Find New Homes</a></li>
# <li><a href="http://www.mls.com/Search/National.mvc">Search MLS Listings</a></li>
# </ul>
# </div>
# <div class="col-md-2 col-sm-4 col-xs-12 fh5co-footer-link">
# <h3>Resources</h3>
# <ul>
# <li><a id="bookmarkme" href="">Bookmark This Site</a></li>
# <li><a href="http://www.mls.com/Contractor.mvc">Home Improvement &amp; Repairs</a></li>
# <li><a href="http://www.mls.com/Education.mvc">Education</a></li>
# <li><a href="http://www.mls.com/Home/Glossary.mvc">Glossary</a></li>
# <li><a href="http://www.mls.com/Home/BuyerSellerInfo.mvc">Buyer/Seller Info</a></li>
# <li><a href="https://www.hud.gov/program_offices/fair_housing_equal_opp" target="_blank">Fair Housing</a></li>
# </ul>
# </div>
# <div class="col-md-6 col-sm-12 col-xs-12">
# <p>
# MLS.com is an independently owned and operated Real Estate
# Advertising Service Company for Real Estate firms, Mortgage firms,
# Insurance companies and other real estate related entities. MLS.com does
# not work directly with any real estate buyers or sellers. MLS.com does
# not receive any commissions or referral fees from any resulting
# transactions. Your use of this web site constitutes your acceptance of
# the MLS.com Privacy Policy and Terms of Use. The mark: "MLS.com
# America's Real Estate Portal" is a servicemark of Multiple Listing
# Network Ltd. The mark 'Realtor' is a servicemark of the National
# Association of Realtors to designate a real estate professional who is a
# member of the National Association of Realtors.
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-6 col-md-offset-3 text-center">
# <p>Copyright 2004 - 2024 <a href="http://www.mls.com/">Multiple Listing Network Ltd</a>. All Rights Reserved.</p>
# </div>
# </div>
# </div>
# </div>
# </footer>
# </div>
# </div>
# </body>
# </html>
