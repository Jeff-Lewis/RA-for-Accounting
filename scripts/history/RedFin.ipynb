# %%
import requests

url = "https://redfin-com-data.p.rapidapi.com/properties/search-sold"

querystring = {"regionId":"6_2446","limit":"1000","soldWithin":"365"}

headers = {
	"X-RapidAPI-Key": "9fb3ebb517mshef1c2cc7b5f6c16p16e0e4jsn72dbf0c17917",
	"X-RapidAPI-Host": "redfin-com-data.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'data': [{'homeData': {'propertyId': '14655619', 'listingId': '171119549', 'listingDisplayLevel': 1, 'mlsId': '23301718', 'url': '/WA/Camas/806-NE-38th-Ave-98607/home/14655619', 'dataSourceId': '84', 'marketId': '10', 'mlsStatusId': '4456', 'servicePolicyId': '4', 'listingMetadata': {'searchStatus': 4, 'listingType': 1, 'isRedfin': True, 'hasVirtualTour': True}, 'propertyType': 6, 'beds': 4, 'baths': 2.5, 'priceInfo': {'amount': '855000', 'displayLevel': 1, 'priceType': 2, 'homePrice': {'displayLevel': 1, 'int64Value': '855000'}}, 'sqftInfo': {'amount': '3400', 'displayLevel': 1}, 'photosInfo': {'photoRanges': [{'startPos': 0, 'endPos': 31, 'version': '0'}], 'primaryPhotoDisplayLevel': 1, 'secondaryPhotoDisplayLevel': 1}, 'daysOnMarket': {'listingAddedDate': '2023-07-10T23:42:13.191Z', 'displayLevel': 1}, 'timezone': 'US/Pacific', 'yearBuilt': {'yearBuilt': 2005, 'displayLevel': 1}, 'lotSize': {'amount': '9583', 'displayLevel': 1}, 'hoaDues': {'displayLevel': 1}, 'sashes': [{'isRedf
# ...

# %%
import json
data = response.json()

print(json.dumps(data, indent=4))
# Out:
# {
#     "data": [
#         {
#             "homeData": {
#                 "propertyId": "14655619",
#                 "listingId": "171119549",
#                 "listingDisplayLevel": 1,
#                 "mlsId": "23301718",
#                 "url": "/WA/Camas/806-NE-38th-Ave-98607/home/14655619",
#                 "dataSourceId": "84",
#                 "marketId": "10",
#                 "mlsStatusId": "4456",
#                 "servicePolicyId": "4",
#                 "listingMetadata": {
#                     "searchStatus": 4,
#                     "listingType": 1,
#                     "isRedfin": true,
#                     "hasVirtualTour": true
#                 },
#                 "propertyType": 6,
#                 "beds": 4,
#                 "baths": 2.5,
#                 "priceInfo": {
#                     "amount": "855000",
#                     "displayLevel": 1,
#                     "priceType": 2,
#                     "homePrice": {
# ...

# %%
print(len(data["data"]))
# Out:
# 479
